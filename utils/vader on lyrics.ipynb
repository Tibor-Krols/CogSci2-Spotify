# %%
import numpy as np
import pandas as pd
import os
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_csv('merged_cleaned_validation.csv')

# %%
df.head()
# Out:
#    Unnamed: 0         artist         trackname  danceability  energy  key  \
# 0           0          CALLA         Strangler         0.527   0.723   11
# 1           1   The Box Tops        The Letter         0.638   0.428    9
# 2           2  Chris Whitley   Big Sky Country         0.663   0.437   10
# 3           3  Chris Garneau    Baby's Romance         0.591   0.326    5
# 4           4   Judy Garland  Over The Rainbow         0.204   0.161    8
#
#    loudness  mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0    -6.695     0       0.0260      0.000066  ...    0.2480    0.540  139.967
# 1   -12.156     0       0.0687      0.252000  ...    0.1320    0.901  139.434
# 2   -11.137     1       0.0330      0.503000  ...    0.0629    0.598   90.169
# 3   -10.393     1       0.0286      0.844000  ...    0.1230    0.176  110.075
# 4   -15.191     1       0.0336      0.972000  ...    0.1210    0.316   82.009
#
#                        id time_signature  \
# 0  5s0tibKDCoGTyncfK7VKzF              4
# 1  6RJK553YhstRzyKA4mug09              4
# 2  3MOHZpSZQmP2f1f30aqpDH              4
# 3  0fVJW7ozV3cnaBdznrmerO              4
# 4  3wAIcORchxdSkWv6v5AkaU              4
#
#                                               lyrics  \
# 0  Something's gotten into your head\mSay what Yo...
# 1  Gimme a ticket for an \maeroplane\mAin't got t...
# 2  Now when this is over\mOver and through\mAnd a...
# 3  [Verse 1]\mThe baby's sleeping in the crib on ...
# 4  [Verse 1]\mSomewhere over the rainbow\mWay up ...
#
#                                       lyrics_cleaned y_valence  y_arousal  \
# 0  Something's gotten into your head Say what You... -1.176640  -0.314720
# 1  Gimme a ticket for an  aeroplane Ain't got tim... -0.780962  -0.789480
# 2  Now when this is over Over and through And all... -0.767318   0.911361
# 3    The baby's sleeping in the crib on top The b... -1.487725  -0.360813
# 4    Somewhere over the rainbow Way up high There...  1.071901   0.846830
#
#                                                vader
# 0  {'neg': 0.012, 'neu': 0.988, 'pos': 0.0, 'comp...
# 1  {'neg': 0.068, 'neu': 0.86, 'pos': 0.072, 'com...
# 2  {'neg': 0.014, 'neu': 0.66, 'pos': 0.326, 'com...
# 3  {'neg': 0.034, 'neu': 0.888, 'pos': 0.078, 'co...
# 4  {'neg': 0.055, 'neu': 0.794, 'pos': 0.152, 'co...
#
# [5 rows x 21 columns]

# %%
# test_lyr = df['lyrics_cleaned'][0]

# %%
# test_lyr

# %%
def get_sentiment(lyrics):
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(lyrics)
    return ss

# %%
# new_df = pd.DataFrame(list(get_sentiment(test_lyr)))

# %%
# new_df

# %%
# get_sentiment(test_lyr)

# %%
# a

# %%
# df['lyrics_cleaned'].iloc[:10]

# %%
# df['lyrics_cleaned'].iloc[:10].apply(lambda x: get_sentiment(x))

# %%
# ser.shape

# %%
# df_feat['lyrics_cleaned'] = df_feat['lyrics'].apply(lambda x: preprocess_text(x))
# df[['neg','neu','pos','compound']] = df['lyrics_cleaned'].iloc[:10].apply(lambda x: get_sentiment(x))

# df['neg'], df['neu'], df['pos'], df['compound']  = df['lyrics_cleaned'].iloc[:10].apply(lambda x: get_sentiment(x))
# df['vader'] = df['lyrics_cleaned'].iloc[:10].apply(lambda x: get_sentiment(x))
df['vader'] = df['lyrics_cleaned'].apply(lambda x: get_sentiment(x))

# %%
# df = df.dropna()

# %%
# df['vader']

# %%
new_df = pd.DataFrame(list(df['vader']))

# %%
df = df.join(new_df, how = 'outer')

# %%
df.drop(columns = 'vader')
# Out:
#       Unnamed: 0         artist          trackname  danceability  energy  key  \
# 0              0          CALLA          Strangler         0.527   0.723   11
# 1              1   The Box Tops         The Letter         0.638   0.428    9
# 2              2  Chris Whitley    Big Sky Country         0.663   0.437   10
# 3              3  Chris Garneau     Baby's Romance         0.591   0.326    5
# 4              4   Judy Garland   Over The Rainbow         0.204   0.161    8
# ...          ...            ...                ...           ...     ...  ...
# 2553        2553      Anastacia     Sick and Tired         0.598   0.868    0
# 2554        2554      Anastacia  Heavy On My Heart         0.478   0.470    1
# 2555        2555     Arch Enemy   The Day You Died         0.135   0.926    5
# 2556        2556     Pink Floyd   Comfortably Numb         0.472   0.366   11
# 2557        2557     Pink Floyd              Money         0.468   0.536   11
#
#       loudness  mode  speechiness  acousticness  ...                      id  \
# 0       -6.695     0       0.0260      0.000066  ...  5s0tibKDCoGTyncfK7VKzF
# 1      -12.156     0       0.0687      0.252000  ...  6RJK553YhstRzyKA4mug09
# 2      -11.137     1       0.0330      0.503000  ...  3MOHZpSZQmP2f1f30aqpDH
# 3      -10.393     1       0.0286      0.844000  ...  0fVJW7ozV3cnaBdznrmerO
# 4      -15.191     1       0.0336      0.972000  ...  3wAIcORchxdSkWv6v5AkaU
# ...        ...   ...          ...           ...  ...                     ...
# 2553    -4.552     1       0.0373      0.009080  ...  54s027DgaSJlvp1q2sdzTa
# 2554    -6.120     0       0.0278      0.148000  ...  6jH4bmYIRZpur97sZZAV4m
# 2555    -3.184     0       0.0776      0.000029  ...  4jVjUOl1gwcHCWxwlWY0zf
# 2556   -12.595     0       0.0286      0.150000  ...  5HNCy40Ni5BZJFw1TKzRsC
# 2557   -10.422     0       0.1440      0.024000  ...  0vFOzaXqZHahrZp6enQwQb
#
#       time_signature                                             lyrics  \
# 0                  4  Something's gotten into your head\mSay what Yo...
# 1                  4  Gimme a ticket for an \maeroplane\mAin't got t...
# 2                  4  Now when this is over\mOver and through\mAnd a...
# 3                  4  [Verse 1]\mThe baby's sleeping in the crib on ...
# 4                  4  [Verse 1]\mSomewhere over the rainbow\mWay up ...
# ...              ...                                                ...
# 2553               4  [Intro]\mMy love is on the line, my love is on...
# 2554               4  [Verse 1]\mI try to fly away but it's impossib...
# 2555               4  [Verse 1]\mA precious child\mWith an innocent ...
# 2556               4  [Intro]\m[Verse 1: Roger Waters]\mHello? (Hell...
# 2557               1  [Intro]\m[Verse 1: David Gilmour]\mMoney, get ...
#
#                                          lyrics_cleaned y_valence  y_arousal  \
# 0     Something's gotten into your head Say what You... -1.176640  -0.314720
# 1     Gimme a ticket for an  aeroplane Ain't got tim... -0.780962  -0.789480
# 2     Now when this is over Over and through And all... -0.767318   0.911361
# 3       The baby's sleeping in the crib on top The b... -1.487725  -0.360813
# 4       Somewhere over the rainbow Way up high There...  1.071901   0.846830
# ...                                                 ...       ...        ...
# 2553    My love is on the line, my love is on the li... -0.431674   0.095510
# 2554    I try to fly away but it's impossible And ev... -1.935250  -0.655810
# 2555    A precious child With an innocent mind Born ... -0.308878  -0.102691
# 2556      Hello? (Hello, hello, hello) Is there anyb... -0.793515  -0.202252
# 2557      Money, get away You get a good job with mo...  0.373325  -0.923151
#
#         neg    neu    pos  compound
# 0     0.012  0.988  0.000   -0.0191
# 1     0.068  0.860  0.072   -0.2697
# 2     0.014  0.660  0.326    0.9986
# 3     0.034  0.888  0.078    0.9264
# 4     0.055  0.794  0.152    0.8633
# ...     ...    ...    ...       ...
# 2553  0.163  0.636  0.202    0.9798
# 2554  0.073  0.748  0.179    0.9884
# 2555  0.360  0.593  0.047   -0.9955
# 2556  0.110  0.761  0.129    0.5022
# 2557  0.089  0.783  0.128    0.6898
#
# [2558 rows x 24 columns]

# %%
df.head()
# Out:
#    Unnamed: 0         artist         trackname  danceability  energy  key  \
# 0           0          CALLA         Strangler         0.527   0.723   11
# 1           1   The Box Tops        The Letter         0.638   0.428    9
# 2           2  Chris Whitley   Big Sky Country         0.663   0.437   10
# 3           3  Chris Garneau    Baby's Romance         0.591   0.326    5
# 4           4   Judy Garland  Over The Rainbow         0.204   0.161    8
#
#    loudness  mode  speechiness  acousticness  ...  time_signature  \
# 0    -6.695     0       0.0260      0.000066  ...               4
# 1   -12.156     0       0.0687      0.252000  ...               4
# 2   -11.137     1       0.0330      0.503000  ...               4
# 3   -10.393     1       0.0286      0.844000  ...               4
# 4   -15.191     1       0.0336      0.972000  ...               4
#
#                                               lyrics  \
# 0  Something's gotten into your head\mSay what Yo...
# 1  Gimme a ticket for an \maeroplane\mAin't got t...
# 2  Now when this is over\mOver and through\mAnd a...
# 3  [Verse 1]\mThe baby's sleeping in the crib on ...
# 4  [Verse 1]\mSomewhere over the rainbow\mWay up ...
#
#                                       lyrics_cleaned  y_valence y_arousal  \
# 0  Something's gotten into your head Say what You...  -1.176640 -0.314720
# 1  Gimme a ticket for an  aeroplane Ain't got tim...  -0.780962 -0.789480
# 2  Now when this is over Over and through And all...  -0.767318  0.911361
# 3    The baby's sleeping in the crib on top The b...  -1.487725 -0.360813
# 4    Somewhere over the rainbow Way up high There...   1.071901  0.846830
#
#                                                vader    neg    neu    pos  \
# 0  {'neg': 0.012, 'neu': 0.988, 'pos': 0.0, 'comp...  0.012  0.988  0.000
# 1  {'neg': 0.068, 'neu': 0.86, 'pos': 0.072, 'com...  0.068  0.860  0.072
# 2  {'neg': 0.014, 'neu': 0.66, 'pos': 0.326, 'com...  0.014  0.660  0.326
# 3  {'neg': 0.034, 'neu': 0.888, 'pos': 0.078, 'co...  0.034  0.888  0.078
# 4  {'neg': 0.055, 'neu': 0.794, 'pos': 0.152, 'co...  0.055  0.794  0.152
#
#    compound
# 0   -0.0191
# 1   -0.2697
# 2    0.9986
# 3    0.9264
# 4    0.8633
#
# [5 rows x 25 columns]

# %%
# new_df.head()

# %%
# df['column_new_1'], df['column_new_2'], df['column_new_3']

# %%
# df.head()

# %%
# sid = SentimentIntensityAnalyzer()
# ss = sid.polarity_scores(test_lyr)
# ss
# # vader_compounds = np.append(ss['compound'],vader_compounds)
